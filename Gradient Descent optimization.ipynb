# %%
import numpy as np

X = np.array([1, 2, 3, 4, 5], dtype=float)
Y = np.array([2, 4, 6, 8, 10], dtype=float)

m = 0
c = 0

learning_rate = 0.01
epochs = 1000

n = len(X)

for i in range(epochs):
    Y_pred = m * X + c    
    
    dm = (-2/n) * sum(X * (Y - Y_pred))
    dc = (-2/n) * sum(Y - Y_pred)
    
    m = m - learning_rate * dm
    c = c - learning_rate * dc
    
    if i % 200 == 0:
        print(f"Epoch {i} → m={m:.4f}, c={c:.4f}")

print("\nFinal equation: y =", round(m, 4), "x +", round(c, 4))
# Out:
# Epoch 0 → m=0.4400, c=0.1200
# Epoch 200 → m=1.9279, c=0.2605
# Epoch 400 → m=1.9634, c=0.1323
# Epoch 600 → m=1.9814, c=0.0672
# Epoch 800 → m=1.9905, c=0.0341
#
# Final equation: y = 1.9952 x + 0.0174
